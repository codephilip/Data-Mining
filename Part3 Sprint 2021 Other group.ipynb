# %% [markdown]
# # Part 3

# %%
\section*{Part 3}

Using the numerical attributes, 0, 3, 4, 7, 9, 11, the multi-variate mean and the covariance matrix were computed. \\

\textbf{Multivariate Mean of numerical data attributes}\\

[54.43333333333333,  249.65925925925927, 0.14814814814814814,\\
1.0499999999999996, 0.6703703703703704, 0.48518518518518516] \\

\textbf{Covariance of the numerical data attributes}

[ 8.29750929e+01  \hspace{2mm}4.44263941e+01  \hspace{2mm}1.03605452e+02 \hspace{2mm}-8.48747212e+01\hspace{2mm}
   2.02620818e+00 \hspace{2mm} 3.06158612e+00]
 [ 4.44263941e+01 \hspace{2mm} 3.19037051e+02 \hspace{2mm} 1.59731185e+02 \hspace{2mm}-1.61934325e+01\hspace{2mm}
   4.55743494e+00 \hspace{2mm} 1.44481619e+00]
 [ 1.03605452e+02 \hspace{2mm} 1.59731185e+02  \hspace{2mm}2.67146711e+03\hspace{2mm} -2.24373399e+01\hspace{2mm}
   1.64014870e+00 \hspace{2mm} 6.17350957e+00]\hspace{2mm}
 [-8.48747212e+01\hspace{2mm} -1.61934325e+01 \hspace{2mm}-2.24373399e+01 \hspace{2mm} 5.36650434e+02\hspace{2mm}
  -9.26003717e+00 \hspace{2mm}-5.80177613e+00]\hspace{2mm}
 [ 2.02620818e+00 \hspace{2mm} 4.55743494e+00 \hspace{2mm} 1.64014870e+00 \hspace{2mm}-9.26003717e+00\hspace{2mm}
   1.31150558e+00  \hspace{2mm}2.75650558e-01]\hspace{2mm}
 [ 3.06158612e+00 \hspace{2mm} 1.44481619e+00 \hspace{2mm} 6.17350957e+00 \hspace{2mm}-5.80177613e+00\hspace{2mm}
   2.75650558e-01\hspace{2mm}  8.90940383e-01]\\

   
   
\textit{The following analysis were done after converting attributes, 2, 6, 12 using one-hot-encoding while the binary and the ordered ones, 1, 5, 8, 10 were considered as label encoded} \\
\begin{itemize}
\item \textbf{Multivariate Mean of the dataset}\\
54.43333333333333, 0.6777777777777778, 131.34444444444443, 249.65925925925927,\\ 0.14814814814814814, 149.67777777777778, 0.3296296296296296, 1.0499999999999996, \\ 1.5851851851851853, 0.6703703703703704, 1.4444444444444444, 0.48518518518518516, \\\ 0.007407407407407408, 0.5074074074074074, 0.07407407407407407, 0.15555555555555556, \\ 0.29259259259259257, 0.4777777777777778, 0.562962962962963, 0.05185185185185185, \\ 0.3851851851851852\\
  \clearpage
\item \textbf{Covariance of the dataset}\\
\includegraphics[scale=0.72]{covdata.pdf}
 \clearpage
\item Choose 5 pairs of attributes that could be related.
\begin{enumerate}
\item Age and serum cholesterol\\
\includegraphics[scale=0.62]{ageSerum.png}

It was expected that there was a correlation between age and the serum cholesterol, taken into consideration that correlation does not imply causation. Plotting the relationship between them, it is observed that there is indeed something interesting about the graph. There are many data points that have clustered together. Their center could be averaged in between 50 and 60 years old intersecting the serum cholesterol level at around 230 mg, which is considered borderline high by the FDA. \url{https://www.accessdata.fda.gov/cdrh_docs/reviews/K063852.pdf}

\item Age and maximum heart rate\\
\includegraphics[scale=0.62]{ageHeart.png}

We correlated the maximum heart rate achieved by the individual to their age. Since older people have to decrease their physical activity at some point, some of their organs could possibly fail to support fully them if the tried to push their limits. The graph pretty much aligns with our initial guess as the maximum heart corresponds to younger peoples. There are a couple of points that maintained the same maximum heart rate while getting older; yet, these could be considered as outliers due to some other parameters that this plot had not reveled.  
\item Age and resting blood pressure\\
\includegraphics[scale=0.62]{ageBlood.png}\\
Since it is known that age and resting blood pressure are correlated to how healthy human beings are, we were really interested to reveal if there was any covariance between these 2 parameters. Again, a scatter plot shows how people in between 50 and 60 years old could be having some physical abnormality. Many clusters are found closer to resting blood pressure of 140, which is where there would be critical risks, according to the FDA. \url{https://www.fda.gov/media/85157/download}
\item Age and number of major vessels\\
\includegraphics[scale=0.62]{ageVessels.png}\\

We were not sure about this correlation as this is could prove either a strong correlation or a weak between heart diseases and age. However, we found out that the data points are scattered in a random way, so this graph could either tell that there is absolutely no correlation or due to some other external factors, no correlation could be caught.   
\newpage
\item Resting blood pressure and serum cholesterol \\
\includegraphics[scale=0.62]{bloodSerum.png}

Knowing that cholesterol is basically a fatty substance and that older people have slower rate of burning  calories than the younger ones. We initially guessed that there could be a correlation that plotting this graph could possibly reveal. This scatter plot did not have solid observations as no noticeable clusters are found at a specific range of number of vessels. There are a couple of reasons why this happened; it could be due to how small the dataset is. The smaller the dataset, the higher impact some outliers can affect the sample. Also, there could be some external parameters that are not considered with respect to either of the number of vessels or the age; yet, they could be affecting the other parameters in an indirect way. Moreover, the graph could be proving that our intuition is not true.    \\
\end{enumerate}

\item Which range-normalized numerical attributes have the greatest sample covariance? What is their sample covariance? Create a scatter plot of these range-normalized attributes\\

Computing the range-normalized for the numerical attributes, it was found out that the ones with the greatest sample covariance are: 
\begin{itemize}
\item Resting blood pressure- Serum cholesterol \textbf{sample covariance= 0.00344041}\\
\includegraphics[scale=0.62]{serum3.png}

\newpage
\item Age- Serum cholesterol of \textbf{sample covariance= 0.00492796}\\
\includegraphics[scale=0.62]{ageSerum3.png}
\end{itemize}

\item Which Z-score-normalized numerical attributes have the greatest correlation? What is their correlation? Create a scatter plot of these Z-score-normalized attributes?

\begin{itemize}
\item Age- Maximum heart rate achieved \textbf{correlation= 0.01349789}\\
\includegraphics[scale=0.62]{34a.png}

\newpage
\item Age- Serum cholesterol of \textbf{correlation= 0.00492796}\\
\includegraphics[scale=0.62]{34b.png}
\end{itemize}





\item Which Z-score-normalized numerical attributes have the smallest correlation? What is their correlation? Create a scatter plot of these Z-score-normalized attributes?
\begin{itemize}
\item Serum cholesterol- Maximum heart rate achieved of \textbf{correlation= -0.00039104}\\
\includegraphics[scale=0.62]{35b.png}\\
\newpage
\item Serum cholesterol- Number of major vessels of \textbf{correlation= 0.00060397}\\
\includegraphics[scale=0.62]{35a.png}
\end{itemize}
\item How many pairs of features have correlation greater than or equal to 0.5?\\
5 pairs of features have hight correlation, greater than or equal to 0.5. 

\item How many pairs of features have negative sample covariance?\\
194 negative values were detected in our covariance matrix. This means that the number of pairs is $\frac{194}{2}$ = 97 pairs. \\
 
\item What is the total variance of the data?\\
3615.226939969713\\

\item What is the total variance of the data, restricted to the five features that have the greatest sample variance?\\
3846.616962687597
\end{itemize}
   
%\[\begin{bmatrix}
% &X_{1}&X_{2}&X_{3}\\
# %x_{1}&0.3&23&5.6\\
# %x_{2}&0.4&1&5.4\\
# %x_{3}&1.8&4&5.2\\
# %x_{4}&6&50&5.1\\
# %x_{5}&-0.5&34&5.3\\
# %x_{6}&0.4&19&5.4\\
# %x_{7}&1.1&11&5.5\\
%\end{bmatrix}\]

\end{document}
